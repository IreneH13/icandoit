# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Irene Haley__ <br>
# I want to be a business consultant focused on people and data

# %% [markdown]
# _I want to be a data scientist because it is interesting and supports new ideas_

# %% [markdown]
# ### add two numbers

# %%
print (1+4)
# Out:
# 5

# %% [markdown]
# #### Bullet list

# %% [markdown]
# - Ping driver
# - calloway irons
# - vega wedges

# %% [markdown]
# #### Numbered list

# %% [markdown]
# 1. Young Frankenstein
# 1. A New Leaf
# 1. The Heat
# 1. The Birdcage

# %% [markdown]
# #### Image

# %% [markdown]
# ![r762637_1296x518_5-2%20%282%29.jpg](attachment:r762637_1296x518_5-2%20%282%29.jpg)
